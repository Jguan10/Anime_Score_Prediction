# %% [markdown]
# Prediction model using episodes, genres, source, synopsis, studios, producers

# %%
#%pip install tensorflow

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/training_set.csv')
df.head(10)
# Out:
#    anime_id                            title  episodes  score  \
# 0         1                     Cowboy Bebop      26.0    9.0
# 1         5  Cowboy Bebop: Tengoku no Tobira       1.0    8.0
# 2         6                           Trigun      26.0    8.0
# 3         7               Witch Hunter Robin      26.0    7.0
# 4         8                   Bouken Ou Beet      52.0    7.0
# 5        15                     Eyeshield 21     145.0    8.0
# 6        16             Hachimitsu to Clover      24.0    8.0
# 7        17       Hungry Heart: Wild Striker      52.0    8.0
# 8        18           Initial D Fourth Stage      24.0    8.0
# 9        19                          Monster      74.0    9.0
#
#   Popularity_category Rank_category  Genres_Action  Genres_Adventure  \
# 0             Top 100       Top 100           True             False
# 1           Top 1,000       Top 500           True             False
# 2             Top 500       Top 500           True             False
# 3           Top 2,500     Top 5,000           True             False
# 4           Top 7,500     Top 5,000           True             False
# 5           Top 2,500     Top 1,000          False             False
# 6           Top 1,000     Top 1,000          False             False
# 7           Top 5,000     Top 2,500          False             False
# 8           Top 2,500       Top 500           True             False
# 9             Top 500       Top 100          False             False
#
#    Genres_Avant Garde  Genres_Award Winning  ...  producer_pony_canyon  \
# 0               False                 False  ...                 False
# 1               False                 False  ...                 False
# 2               False                 False  ...                 False
# 3               False                 False  ...                 False
# 4               False                 False  ...                 False
# 5               False                 False  ...                 False
# 6               False                 False  ...                 False
# 7               False                 False  ...                 False
# 8               False                 False  ...                 False
# 9               False                 False  ...                 False
#
#    producer_kadokawa  producer_dentsu  producer_fuji_tv  producer_nhk  \
# 0              False            False             False         False
# 1              False            False             False         False
# 2              False            False             False         False
# 3              False             True             False         False
# 4              False             True             False         False
# 5              False            False             False         False
# 6              False             True              True         False
# 7              False            False             False         False
# 8              False            False             False         False
# 9              False            False             False         False
#
#    producer_sotsu  producer_klockworx  producer_kodansha  producer_shueisha  \
# 0           False               False              False              False
# 1           False               False              False              False
# 2           False               False              False              False
# 3           False               False              False              False
# 4           False               False              False              False
# 5           False               False              False               True
# 6           False               False              False               True
# 7           False               False              False              False
# 8           False               False              False              False
# 9           False               False              False              False
#
#      year
# 0  1998.0
# 1     NaN
# 2  1998.0
# 3  2002.0
# 4  2004.0
# 5  2005.0
# 6  2005.0
# 7  2002.0
# 8  2004.0
# 9  2004.0
#
# [10 rows x 239 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21280 entries, 0 to 21279
# Columns: 239 entries, anime_id to year
# dtypes: bool(79), float64(154), int64(2), object(4)
# memory usage: 27.6+ MB

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
scaler = preprocessing.MinMaxScaler()
df[["episodes"]] = scaler.fit_transform(df[["episodes"]])

# %%
most_common = df["Popularity_category"].value_counts().idxmax()  
df["Popularity_category"] = df["Popularity_category"].replace("Unknown", most_common)

# %%
most_common = df["Rank_category"].value_counts().idxmax()  
df["Rank_category"] = df["Rank_category"].replace("Unknown", most_common)
df["Rank_category"] = df["Rank_category"].replace("Top 10", "Top 100")
df["Popularity_category"] = df["Popularity_category"].replace("Top 10", "Top 100")

# %%
df['score'] = df['score'].round().astype(int)
df['score'] = df['score'].astype(str)

# %%
#X_train = df.drop(columns=["anime_id","title","score", "popularity", "rank", "Popularity_category", "Rank_category", "studios"])
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=["anime_id","title","score", "popularity", "rank", "Popularity_category", "Rank_category", "studios", "year"]),
    df[["score", "Popularity_category", "Rank_category"]],
    test_size=0.2, 
    random_state=42  
)

# %%
score_encoder = LabelEncoder()
popularity_encoder = LabelEncoder()
rank_encoder = LabelEncoder()

y_score_encoded = score_encoder.fit_transform(y_train['score'])

y_pop_encoded = popularity_encoder.fit_transform(y_train['Popularity_category'])

y_rank_encoded = rank_encoder.fit_transform(y_train['Rank_category'])

# %%
y_score = to_categorical(y_score_encoded)

y_pop = to_categorical(y_pop_encoded)

y_rank = to_categorical(y_rank_encoded)

# %%
input_layer = Input(shape=(X_train.shape[1],))
hidden_layer = Dense(64, activation='relu')(input_layer)
shared_layer = Dense(64, activation='relu')(input_layer)
shared_layer = Dense(64, activation='relu')(shared_layer)

# %%
score_output = Dense(y_score.shape[1], activation='softmax', name="score")(shared_layer)
popularity_output = Dense(y_pop.shape[1], activation='softmax', name="popularity")(shared_layer)
rank_output = Dense(y_rank.shape[1], activation='softmax', name="rank")(shared_layer)

# %%
model = Model(inputs=input_layer, outputs=[score_output, popularity_output, rank_output])

model.compile(optimizer='adam',
              loss={'score': 'categorical_crossentropy',
                    'popularity': 'categorical_crossentropy',
                    'rank': 'categorical_crossentropy'},
              metrics={
                  'score': ['accuracy'],
                  'popularity': ['accuracy'], 
                  'rank': ['accuracy']  
                  })

# %%
history = model.fit(X_train,
                    {'score': y_score, 'popularity': y_pop, 'rank': y_rank},
                    validation_split=0.2,
                    epochs=50,
                    batch_size=128)
# Out:
# Epoch 1/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 5.5343 - popularity_accuracy: 0.4649 - popularity_loss: 1.8988 - rank_accuracy: 0.3413 - rank_loss: 1.8434 - score_accuracy: 0.3366 - score_loss: 1.7919 - val_loss: 3.4674 - val_popularity_accuracy: 0.5295 - val_popularity_loss: 1.2850 - val_rank_accuracy: 0.5524 - val_rank_loss: 1.1975 - val_score_accuracy: 0.6256 - val_score_loss: 0.9871
# Epoch 2/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3523 - popularity_accuracy: 0.5394 - popularity_loss: 1.2407 - rank_accuracy: 0.5722 - rank_loss: 1.1509 - score_accuracy: 0.6296 - score_loss: 0.9607 - val_loss: 3.1592 - val_popularity_accuracy: 0.5903 - val_popularity_loss: 1.1169 - val_rank_accuracy: 0.5715 - val_rank_loss: 1.1157 - val_score_accuracy: 0.6232 - val_score_loss: 0.9275
# Epoch 3/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0760 - popularity_accuracy: 0.5696 - popularity_loss: 1.1118 - rank_accuracy: 0.5965 - rank_loss: 1.0659 - score_accuracy: 0.6443 - score_loss: 0.8983 - val_loss: 3.0779 - val_popularity_accuracy: 0.5903 - val_popularity_loss: 1.0737 - val_rank_accuracy: 0.5733 - val_rank_loss: 1.0935 - val_score_accuracy: 0.6352 - val_score_loss: 0.9112
# Epoch 4/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9968 - popularity_accuracy: 0.5823 - popularity_loss: 1.0776 - rank_accuracy: 0.5956 - rank_loss: 1.0553 - score_accuracy: 0.6541 - score_loss: 0.8638 - val_loss: 3.0221 - val_popularity_accuracy: 0.5912 - val_popularity_loss: 1.0504 - val_rank_accuracy: 0.5824 - val_rank_loss: 1.0815 - val_score_accuracy: 0.6396 - val_score_loss: 0.8909
# Epoch 5/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9377 - popularity_accuracy: 0.5841 - popularity_loss: 1.0517 - rank_accuracy: 0.6049 - rank_loss: 1.0383 - score_accuracy: 0.6600 - score_loss: 0.8477 - val_loss: 2.9907 - val_popularity_accuracy: 0.5944 - val_popularity_loss: 1.0356 - val_rank_accuracy: 0.5868 - val_rank_loss: 1.0733 - val_score_accuracy: 0.6417 - val_score_loss: 0.8826
# Epoch 6/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8698 - popularity_accuracy: 0.5939 - popularity_loss: 1.0216 - rank_accuracy: 0.6171 - rank_loss: 1.0120 - score_accuracy: 0.6682 - score_loss: 0.8361 - val_loss: 2.9892 - val_popularity_accuracy: 0.5956 - val_popularity_loss: 1.0365 - val_rank_accuracy: 0.5859 - val_rank_loss: 1.0665 - val_score_accuracy: 0.6408 - val_score_loss: 0.8867
# Epoch 7/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8372 - popularity_accuracy: 0.5964 - popularity_loss: 1.0165 - rank_accuracy: 0.6168 - rank_loss: 1.0031 - score_accuracy: 0.6719 - score_loss: 0.8176 - val_loss: 2.9573 - val_popularity_accuracy: 0.5941 - val_popularity_loss: 1.0229 - val_rank_accuracy: 0.5912 - val_rank_loss: 1.0599 - val_score_accuracy: 0.6490 - val_score_loss: 0.8746
# Epoch 8/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8413 - popularity_accuracy: 0.5912 - popularity_loss: 1.0234 - rank_accuracy: 0.6207 - rank_loss: 0.9939 - score_accuracy: 0.6657 - score_loss: 0.8240 - val_loss: 2.9658 - val_popularity_accuracy: 0.5941 - val_popularity_loss: 1.0250 - val_rank_accuracy: 0.5877 - val_rank_loss: 1.0643 - val_score_accuracy: 0.6488 - val_score_loss: 0.8774
# Epoch 9/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7673 - popularity_accuracy: 0.6099 - popularity_loss: 0.9981 - rank_accuracy: 0.6235 - rank_loss: 0.9719 - score_accuracy: 0.6748 - score_loss: 0.7973 - val_loss: 2.9636 - val_popularity_accuracy: 0.6023 - val_popularity_loss: 1.0270 - val_rank_accuracy: 0.5880 - val_rank_loss: 1.0615 - val_score_accuracy: 0.6499 - val_score_loss: 0.8755
# Epoch 10/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7306 - popularity_accuracy: 0.6183 - popularity_loss: 0.9810 - rank_accuracy: 0.6317 - rank_loss: 0.9647 - score_accuracy: 0.6876 - score_loss: 0.7848 - val_loss: 2.9524 - val_popularity_accuracy: 0.5979 - val_popularity_loss: 1.0202 - val_rank_accuracy: 0.5918 - val_rank_loss: 1.0597 - val_score_accuracy: 0.6535 - val_score_loss: 0.8728
# Epoch 11/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7223 - popularity_accuracy: 0.6225 - popularity_loss: 0.9690 - rank_accuracy: 0.6351 - rank_loss: 0.9640 - score_accuracy: 0.6808 - score_loss: 0.7894 - val_loss: 2.9472 - val_popularity_accuracy: 0.6009 - val_popularity_loss: 1.0167 - val_rank_accuracy: 0.5909 - val_rank_loss: 1.0566 - val_score_accuracy: 0.6517 - val_score_loss: 0.8749
# Epoch 12/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6980 - popularity_accuracy: 0.6195 - popularity_loss: 0.9720 - rank_accuracy: 0.6372 - rank_loss: 0.9491 - score_accuracy: 0.6900 - score_loss: 0.7769 - val_loss: 2.9485 - val_popularity_accuracy: 0.6032 - val_popularity_loss: 1.0105 - val_rank_accuracy: 0.5927 - val_rank_loss: 1.0575 - val_score_accuracy: 0.6408 - val_score_loss: 0.8814
# Epoch 13/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6649 - popularity_accuracy: 0.6253 - popularity_loss: 0.9555 - rank_accuracy: 0.6428 - rank_loss: 0.9403 - score_accuracy: 0.6914 - score_loss: 0.7690 - val_loss: 2.9474 - val_popularity_accuracy: 0.6032 - val_popularity_loss: 1.0130 - val_rank_accuracy: 0.5891 - val_rank_loss: 1.0587 - val_score_accuracy: 0.6573 - val_score_loss: 0.8766
# Epoch 14/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6113 - popularity_accuracy: 0.6362 - popularity_loss: 0.9296 - rank_accuracy: 0.6455 - rank_loss: 0.9258 - score_accuracy: 0.6932 - score_loss: 0.7560 - val_loss: 2.9476 - val_popularity_accuracy: 0.6026 - val_popularity_loss: 1.0154 - val_rank_accuracy: 0.5927 - val_rank_loss: 1.0566 - val_score_accuracy: 0.6552 - val_score_loss: 0.8759
# Epoch 15/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6006 - popularity_accuracy: 0.6299 - popularity_loss: 0.9372 - rank_accuracy: 0.6465 - rank_loss: 0.9181 - score_accuracy: 0.6999 - score_loss: 0.7454 - val_loss: 2.9631 - val_popularity_accuracy: 0.6070 - val_popularity_loss: 1.0172 - val_rank_accuracy: 0.5959 - val_rank_loss: 1.0639 - val_score_accuracy: 0.6529 - val_score_loss: 0.8827
# Epoch 16/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5856 - popularity_accuracy: 0.6317 - popularity_loss: 0.9342 - rank_accuracy: 0.6499 - rank_loss: 0.9120 - score_accuracy: 0.7076 - score_loss: 0.7395 - val_loss: 2.9674 - val_popularity_accuracy: 0.6044 - val_popularity_loss: 1.0153 - val_rank_accuracy: 0.5918 - val_rank_loss: 1.0700 - val_score_accuracy: 0.6561 - val_score_loss: 0.8821
# Epoch 17/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5716 - popularity_accuracy: 0.6396 - popularity_loss: 0.9232 - rank_accuracy: 0.6538 - rank_loss: 0.9096 - score_accuracy: 0.7017 - score_loss: 0.7388 - val_loss: 2.9642 - val_popularity_accuracy: 0.6088 - val_popularity_loss: 1.0135 - val_rank_accuracy: 0.5906 - val_rank_loss: 1.0691 - val_score_accuracy: 0.6529 - val_score_loss: 0.8827
# Epoch 18/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5285 - popularity_accuracy: 0.6422 - popularity_loss: 0.9135 - rank_accuracy: 0.6537 - rank_loss: 0.8936 - score_accuracy: 0.7067 - score_loss: 0.7214 - val_loss: 2.9786 - val_popularity_accuracy: 0.5991 - val_popularity_loss: 1.0149 - val_rank_accuracy: 0.5903 - val_rank_loss: 1.0739 - val_score_accuracy: 0.6479 - val_score_loss: 0.8902
# Epoch 19/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.
50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3347 - popularity_accuracy: 0.6606 - popularity_loss: 0.8612 - rank_accuracy: 0.6767 - rank_loss: 0.8201 - score_accuracy: 0.7454 - score_loss: 0.6534 - val_loss: 3.0716 - val_popularity_accuracy: 0.6021 - val_popularity_loss: 1.0300 - val_rank_accuracy: 0.5959 - val_rank_loss: 1.1176 - val_score_accuracy: 0.6432 - val_score_loss: 0.9250
# Epoch 28/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3012 - popularity_accuracy: 0.6636 - popularity_loss: 0.8535 - rank_accuracy: 0.6855 - rank_loss: 0.8009 - score_accuracy: 0.7455 - score_loss: 0.6469 - val_loss: 3.0884 - val_popularity_accuracy: 0.6023 - val_popularity_loss: 1.0317 - val_rank_accuracy: 0.6000 - val_rank_loss: 1.1253 - val_score_accuracy: 0.6467 - val_score_loss: 0.9323
# Epoch 29/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3096 - popularity_accuracy: 0.6624 - popularity_loss: 0.8537 - rank_accuracy: 0.6885 - rank_loss: 0.8074 - score_accuracy: 0.7453 - score_loss: 0.6485 - val_loss: 3.1069 - val_popularity_accuracy: 0.6056 - val_popularity_loss: 1.0348 - val_rank_accuracy: 0.5982 - val_rank_loss: 1.1320 - val_score_accuracy: 0.6349 - val_score_loss: 0.9410
# Epoch 30/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2718 - popularity_accuracy: 0.6707 - popularity_loss: 0.8470 - rank_accuracy: 0.6919 - rank_loss: 0.7949 - score_accuracy: 0.7561 - score_loss: 0.6299 - val_loss: 3.1116 - val_popularity_accuracy: 0.6021 - val_popularity_loss: 1.0376 - val_rank_accuracy: 0.5909 - val_rank_loss: 1.1330 - val_score_accuracy: 0.6382 - val_score_loss: 0.9423
# Epoch 31/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2814 - popularity_accuracy: 0.6684 - popularity_loss: 0.8474 - rank_accuracy: 0.6905 - rank_loss: 0.8014 - score_accuracy: 0.7545 - score_loss: 0.6327 - val_loss: 3.1265 - val_popularity_accuracy: 0.6026 - val_popularity_loss: 1.0399 - val_rank_accuracy: 0.5909 - val_rank_loss: 1.1419 - val_score_accuracy: 0.6449 - val_score_loss: 0.9453
# Epoch 32/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1943 - popularity_accuracy: 0.6737 - popularity_loss: 0.8196 - rank_accuracy: 0.6955 - rank_loss: 0.7743 - score_accuracy: 0.7697 - score_loss: 0.6004 - val_loss: 3.1376 - val_popularity_accuracy: 0.5968 - val_popularity_loss: 1.0437 - val_rank_accuracy: 0.5915 - val_rank_loss: 1.1471 - val_score_accuracy: 0.6323 - val_score_loss: 0.9479
# Epoch 33/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1800 - popularity_accuracy: 0.6780 - popularity_loss: 0.8201 - rank_accuracy: 0.7065 - rank_loss: 0.7573 - score_accuracy: 0.7698 - score_loss: 0.6026 - val_loss: 3.1733 - val_popularity_accuracy: 0.5930 - val_popularity_loss: 1.0496 - val_rank_accuracy: 0.5862 - val_rank_loss: 1.1622 - val_score_accuracy: 0.6382 - val_score_loss: 0.9623
# Epoch 34/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.
50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0621 - popularity_accuracy: 0.6825 - popularity_loss: 0.7936 - rank_accuracy: 0.7246 - rank_loss: 0.7134 - score_accuracy: 0.7863 - score_loss: 0.5551 - val_loss: 3.3273 - val_popularity_accuracy: 0.5971 - val_popularity_loss: 1.0814 - val_rank_accuracy: 0.5833 - val_rank_loss: 1.2234 - val_score_accuracy: 0.6317 - val_score_loss: 1.0226
# Epoch 43/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0500 - popularity_accuracy: 0.6849 - popularity_loss: 0.7861 - rank_accuracy: 0.7246 - rank_loss: 0.7131 - score_accuracy: 0.7896 - score_loss: 0.5508 - val_loss: 3.3536 - val_popularity_accuracy: 0.5894 - val_popularity_loss: 1.0839 - val_rank_accuracy: 0.5821 - val_rank_loss: 1.2319 - val_score_accuracy: 0.6297 - val_score_loss: 1.0397
# Epoch 44/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0394 - popularity_accuracy: 0.6825 - popularity_loss: 0.7996 - rank_accuracy: 0.7237 - rank_loss: 0.7021 - score_accuracy: 0.7912 - score_loss: 0.5377 - val_loss: 3.3759 - val_popularity_accuracy: 0.5918 - val_popularity_loss: 1.0879 - val_rank_accuracy: 0.5786 - val_rank_loss: 1.2445 - val_score_accuracy: 0.6320 - val_score_loss: 1.0440
# Epoch 45/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0070 - popularity_accuracy: 0.6891 - popularity_loss: 0.7826 - rank_accuracy: 0.7262 - rank_loss: 0.6964 - score_accuracy: 0.7975 - score_loss: 0.5280 - val_loss: 3.3952 - val_popularity_accuracy: 0.5912 - val_popularity_loss: 1.0947 - val_rank_accuracy: 0.5806 - val_rank_loss: 1.2500 - val_score_accuracy: 0.6349 - val_score_loss: 1.0500
# Epoch 46/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0127 - popularity_accuracy: 0.6824 - popularity_loss: 0.7834 - rank_accuracy: 0.7298 - rank_loss: 0.6955 - score_accuracy: 0.7955 - score_loss: 0.5338 - val_loss: 3.4181 - val_popularity_accuracy: 0.5900 - val_popularity_loss: 1.0981 - val_rank_accuracy: 0.5862 - val_rank_loss: 1.2655 - val_score_accuracy: 0.6256 - val_score_loss: 1.0554
# Epoch 47/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9968 - popularity_accuracy: 0.6870 - popularity_loss: 0.7782 - rank_accuracy: 0.7277 - rank_loss: 0.6892 - score_accuracy: 0.7983 - score_loss: 0.5295 - val_loss: 3.4511 - val_popularity_accuracy: 0.5871 - val_popularity_loss: 1.1061 - val_rank_accuracy: 0.5736 - val_rank_loss: 1.2740 - val_score_accuracy: 0.6267 - val_score_loss: 1.0713
# Epoch 48/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9964 - popularity_accuracy: 0.6886 - popularity_loss: 0.7861 - rank_accuracy: 0.7353 - rank_loss: 0.6873 - score_accuracy: 0.8047 - score_loss: 0.5230 - val_loss: 3.4677 - val_popularity_accuracy: 0.5932 - val_popularity_loss: 1.1027 - val_rank_accuracy: 0.5803 - val_rank_loss: 1.2841 - val_score_accuracy: 0.6302 - val_score_loss: 1.0814
# Epoch 49/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9348 - popularity_accuracy: 0.6938 - popularity_loss: 0.7627 - rank_accuracy: 0.7423 - rank_loss: 0.6633 - score_accuracy: 0.8076 - score_loss: 0.5088 - val_loss: 3.4862 - val_popularity_accuracy: 0.5888 - val_popularity_loss: 1.1116 - val_rank_accuracy: 0.5821 - val_rank_loss: 1.2920 - val_score_accuracy: 0.6226 - val_score_loss: 1.0822
# Epoch 50/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9424 - popularity_accuracy: 0.6933 - popularity_loss: 0.7687 - rank_accuracy: 0.7473 - rank_loss: 0.6645 - score_accuracy: 0.8093 - score_loss: 0.5092 - val_loss: 3.5013 - val_popularity_accuracy: 0.5912 - val_popularity_loss: 1.1128 - val_rank_accuracy: 0.5783 - val_rank_loss: 1.2968 - val_score_accuracy: 0.6256 - val_score_loss: 1.0927

# %%
y_pred = model.predict(X_test)
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred_score = y_pred[0].argmax(axis=1)
y_pred_score = score_encoder.inverse_transform(y_pred_score)

y_pred_pop = y_pred[1].argmax(axis=1)
y_pred_pop = popularity_encoder.inverse_transform(y_pred_pop)

y_pred_rank = y_pred[2].argmax(axis=1)
y_pred_rank = rank_encoder.inverse_transform(y_pred_rank)

# %%
accuracy_score_score = accuracy_score(y_test['score'], y_pred_score)
accuracy_score_pop = accuracy_score(y_test['Popularity_category'], y_pred_pop)
accuracy_score_rank = accuracy_score(y_test['Rank_category'], y_pred_rank)

print(f"Accuracy for Score Prediction: {accuracy_score_score:.4f}")
print(f"Accuracy for Popularity Category Prediction: {accuracy_score_pop:.4f}")
print(f"Accuracy for Rank Category Prediction: {accuracy_score_rank:.4f}")

# %%
popularity_encoder.classes_
# Out:
# array(['Top 1,000', 'Top 10,000', 'Top 100', 'Top 2,500', 'Top 25,000',
#        'Top 5,000', 'Top 50,000', 'Top 500', 'Top 7,500'], dtype=object)

# %%
category_labels = ['Top 100', 'Top 500', 'Top 1,000', 'Top 2,500', 
                     'Top 5,000', 'Top 7,500', 'Top 10,000', 'Top 25,000', 'Top 50,000']

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_score = confusion_matrix(y_test['score'], y_pred_score, labels=score_encoder.classes_)
cm_pop = confusion_matrix(y_test['Popularity_category'], y_pred_pop, labels=category_labels)
cm_rank = confusion_matrix(y_test['Rank_category'], y_pred_rank, labels=category_labels)

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

disp_score = ConfusionMatrixDisplay(confusion_matrix=cm_score, display_labels=score_encoder.classes_)
disp_score.plot(cmap=plt.cm.Blues, ax=axs[0], xticks_rotation='vertical')
axs[0].set_title('Confusion Matrix for Score Prediction')

disp_pop = ConfusionMatrixDisplay(confusion_matrix=cm_pop, display_labels=category_labels)
disp_pop.plot(cmap=plt.cm.Blues, ax=axs[1], xticks_rotation='vertical')
axs[1].set_title('Confusion Matrix for Popularity Category Prediction')

disp_rank = ConfusionMatrixDisplay(confusion_matrix=cm_rank, display_labels=category_labels)
disp_rank.plot(cmap=plt.cm.Blues, ax=axs[2], xticks_rotation='vertical')
axs[2].set_title('Confusion Matrix for Rank Category Prediction')

plt.tight_layout()
plt.show()

# %%
model.save('prediction_model.keras')
